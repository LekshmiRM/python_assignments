# %% [markdown]
# <a href="https://colab.research.google.com/github/LekshmiRM/python_assignments/blob/main/Case_Study_SQL_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Case Study on SQL

# %%
import sqlite3
import pandas as pd

# %%
def load_imdb_database(db_path):
  try:
    conn = sqlite3.connect(db_path)
    print("IMDB database loaded successfully.")
    return conn
  except sqlite3.Error as e:
    print(f"Error loading IMDB database: {e}")
    return None

# %%
db_path = "imdb.db"
conn = load_imdb_database(db_path)

if conn:
  print("Connection successful")
  cursor = conn.cursor()
# Out:
# IMDB database loaded successfully.
# Connection successful

# %% [markdown]
# ## Following is the schema of the IMDB database. It lists all tables and their schemas.

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

print("Database Schema:")
for table in tables:
    table_name = table[0]
    print(f"\nTable: {table_name}")

    cursor.execute(f"PRAGMA table_info({table_name});")
    schema = cursor.fetchall()

    print("Columns:")
    for column in schema:
        cid, name, dtype, notnull, dflt_value, pk = column
        print(f"  - {name} ({dtype}), NOT NULL: {bool(notnull)}, Default: {dflt_value}, Primary Key: {bool(pk)}")
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipython-input-2169833093.py in <cell line: 0>()
# ----> 1 cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
#       2 tables = cursor.fetchall()
#       3
#       4 print("Database Schema:")
#       5 for table in tables:
#
# DatabaseError: database disk image is malformed

# %% [markdown]
# # Write SQL queries for the following questions

# %% [markdown]
# ## 1. Write query to list first 5 rows of Person table

# %%
q1=cursor.execute("select * from Person LIMIT 5")
rows=cursor.fetchall()
print(rows)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipython-input-2350394306.py in <cell line: 0>()
# ----> 1 q1=cursor.execute("select * from Person LIMIT 5")
#       2 rows=cursor.fetchall()
#       3 print(rows)
#
# DatabaseError: database disk image is malformed

# %%
def q1_grader(q1):
  result = pd.read_sql_query(q1, conn)
  return result.shape == (5, 4)
print(q1_grader(q1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1619397838.py in <cell line: 0>()
#       2   result = pd.read_sql_query(q1, conn)
#       3   return result.shape == (5, 4)
# ----> 4 print(q1_grader(q1))
#
# NameError: name 'q1' is not defined

# %% [markdown]
# ## 2. Write query to select title, year and rating from Movie table

# %%
q2 =cursor.execute( "select title,year,rating FROM Movie")
rows=cursor.fetchall()
print(rows)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipython-input-3261770556.py in <cell line: 0>()
# ----> 1 q2 =cursor.execute( "select title,year,rating FROM Movie")
#       2 rows=cursor.fetchall()
#       3 print(rows)
#
# DatabaseError: database disk image is malformed

# %%
def q2_grader(q2):
  result = pd.read_sql_query(q2, conn)
  return result.shape == (3473, 3) and result['title'][0]=='Mowgli'
print(q2_grader(q2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3643069964.py in <cell line: 0>()
#       2   result = pd.read_sql_query(q2, conn)
#       3   return result.shape == (3473, 3) and result['title'][0]=='Mowgli'
# ----> 4 print(q2_grader(q2))
#
# NameError: name 'q2' is not defined

# %% [markdown]
# ## 3. Write query to get title of first movie in movie table sorted by year in ascending order

# %%
q3 = cursor.execute("select title from Movie ORDER BY year ASC LIMIT 1")
rows=cursor.fetchall()
print(rows)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipython-input-2000057249.py in <cell line: 0>()
# ----> 1 q3 = cursor.execute("select title from Movie ORDER BY year ASC LIMIT 1")
#       2 rows=cursor.fetchall()
#       3 print(rows)
#
# DatabaseError: database disk image is malformed

# %%
def q3_grader(q3):
  result = pd.read_sql_query(q3, conn)
  return result['title']=='Alam Ara'
print(q3_grader(q3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-445096487.py in <cell line: 0>()
#       2   result = pd.read_sql_query(q3, conn)
#       3   return result['title']=='Alam Ara'
# ----> 4 print(q3_grader(q3))
#
# NameError: name 'q3' is not defined

# %% [markdown]
# ## 4. Write query to get the very first year in which Devdas movie was released

# %%
q4 = cursor.execute("select MIN(year) AS first_release_year FROM Movie WHERE title='Devdas'")
rows=cursor.fetchall()
print(rows)

# %%
def q4_grader(q4):
  result = pd.read_sql_query(q4, conn)
  return result['year']=='1936'
print(q4_grader(q4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3803374630.py in <cell line: 0>()
#       2   result = pd.read_sql_query(q4, conn)
#       3   return result['year']=='1936'
# ----> 4 print(q4_grader(q4))
#
# NameError: name 'q4' is not defined

# %% [markdown]
# ## 5. Write query to get the number of movies released in 2018

# %%
q5 = cursor.execute("select COUNT(*) AS movie_2018 FROM Movie WHERE year=2018")
rows=cursor.fetchall()
print(rows)

# %%
def q5_grader(q5):
  result = pd.read_sql_query(q5, conn)
  return result.iloc[0, 0] == 93
print(q5_grader(q5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-388201604.py in <cell line: 0>()
#       2   result = pd.read_sql_query(q5, conn)
#       3   return result.iloc[0, 0] == 93
# ----> 4 print(q5_grader(q5))
#
# NameError: name 'q5' is not defined

# %% [markdown]
# **6.Write query to get the title of the movie with most number of votes in 2012**

# %%
q6 = cursor.execute("select title FROM Movie WHERE year=2012 ORDER BY num_votes DESC LIMIT 1")
rows=cursor.fetchall()
print(rows)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipython-input-1494757386.py in <cell line: 0>()
# ----> 1 q6 = cursor.execute("select title FROM Movie WHERE year=2012 ORDER BY num_votes DESC LIMIT 1")
#       2 rows=cursor.fetchall()
#       3 print(rows)
#
# DatabaseError: database disk image is malformed

# %%
def q6_grader(q6):
  result = pd.read_sql_query(q6, conn)
  return result["title"]=="The Avengers"
print(q6_grader(q6))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-261686200.py in <cell line: 0>()
#       2   result = pd.read_sql_query(q6, conn)
#       3   return result["title"]=="The Avengers"
# ----> 4 print(q6_grader(q6))
#
# NameError: name 'q6' is not defined

# %% [markdown]
# ## 7. Write SQL query to find all the unique movie titles released in 2018

# %%
q7 = cursor.execute("select DISTINCT title FROM Movie WHERE year =2018")
rows=cursor.fetchall()
print(rows)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipython-input-198585134.py in <cell line: 0>()
# ----> 1 q7 = cursor.execute("select DISTINCT title FROM Movie WHERE year =2018")
#       2 rows=cursor.fetchall()
#       3 print(rows)
#
# DatabaseError: database disk image is malformed

# %%
def q7_grader(q7):
  result = pd.read_sql_query(q7, conn)
  return result.shape==(93, 1)
print(q7_grader(q7))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1909003882.py in <cell line: 0>()
#       2   result = pd.read_sql_query(q7, conn)
#       3   return result.shape==(93, 1)
# ----> 4 print(q7_grader(q7))
#
# NameError: name 'q7' is not defined

# %% [markdown]
# ## 8. Write SQL query to get total number of movies released between 2017 (inclusive) and 2018 (inclusive)

# %%
q8 = cursor.execute("select COUNT(*) AS total_movies FROM Movie WHERE year between 2017 AND 2018")
rows=cursor.fetchall()
print(rows)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipython-input-2548922422.py in <cell line: 0>()
# ----> 1 q8 = cursor.execute("select COUNT(*) AS total_movies FROM Movie WHERE year between 2017 AND 2018")
#       2 rows=cursor.fetchall()
#       3 print(rows)
#
# DatabaseError: database disk image is malformed

# %%
def q8_grader(q8):
  result = pd.read_sql_query(q8, conn)
  return result.iloc[0, 0] == 211
print(q8_grader(q8))

# %% [markdown]
# ## 9. Write SQL query to find the year in which maximum number of movies released

# %%
q9 = cursor.execute("select year FROM Movie GROUP BY year ORDER BY COUNT(*) DESC LIMIT 1")
rows=cursor.fetchall()
print(rows)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipython-input-124160646.py in <cell line: 0>()
# ----> 1 q9 = cursor.execute("select year FROM Movie GROUP BY year ORDER BY COUNT(*) DESC LIMIT 1")
#       2 rows=cursor.fetchall()
#       3 print(rows)
#
# DatabaseError: database disk image is malformed

# %%
def q9_grader(q9):
  result = pd.read_sql_query(q9, conn)
  return result["year"][0]=="2005"
print(q9_grader(q9))

# %% [markdown]
# ## 10. Write SQL query to find the title of the movie with rating>9.5 and number of votes > 90

# %%
q10 =cursor.execute( "select title FROM Movie WHERE rating >9.5 AND num_votes>90")
rows=cursor.fetchall()
print(rows)

# %%
def q10_grader(q10):
  result = pd.read_sql_query(q10, conn)
  return result["title"][0]=="Man on Mission Fauladi"
print(q10_grader(q10))

# %% [markdown]
# ## 11. Write SQL query to find the number of movies which has the word 'Dilwale' in their title

# %%
q11 = cursor.execute("select COUNT(*) AS num_movie FROM Movie WHERE title LIKE '%Dilwale%'")
rows=cursor.fetchall()
print(rows)

# %%
def q11_grader(q11):
  result = pd.read_sql_query(q11, conn)
  return result.iloc[0, 0] == 4
print(q11_grader(q11))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-433103982.py in <cell line: 0>()
#       2   result = pd.read_sql_query(q11, conn)
#       3   return result.iloc[0, 0] == 4
# ----> 4 print(q11_grader(q11))
#
# NameError: name 'q11' is not defined

# %% [markdown]
# ## 12. Write nested SQL query to find the CID of country which produced most number of movies

# %%
q12 = cursor.execute("select CID FROM M_Country GROUP BY CID HAVING COUNT(MID)=(SELECT MAX(movie_count) FROM(select COUNT(MID) AS movie_count FROM M_Country GROUP BY CID))")
rows=cursor.fetchall()
print(rows)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipython-input-3649059527.py in <cell line: 0>()
# ----> 1 q12 = cursor.execute("select CID FROM M_Country GROUP BY CID HAVING COUNT(MID)=(SELECT MAX(movie_count) FROM(select COUNT(MID) AS movie_count FROM M_Country GROUP BY CID))")
#       2 rows=cursor.fetchall()
#       3 print(rows)
#
# DatabaseError: database disk image is malformed

# %%
def q12_grader(q12):
  result = pd.read_sql_query(q12, conn)
  return result.iloc[0]==2.0
print(q12_grader(q12))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3146322673.py in <cell line: 0>()
#       2   result = pd.read_sql_query(q12, conn)
#       3   return result.iloc[0]==2.0
# ----> 4 print(q12_grader(q12))
#
# NameError: name 'q12' is not defined

# %% [markdown]
# ## 13. Write nested SQL query to the country which produced most number of movies (use both Courty table and M_Country table)

# %%
q13 = cursor.execute("select name from Country WHERE CID =(select CID FROM M_Country GROUP BY CID ORDER BY COUNT(*) DESC LIMIT 1) ")
rows=cursor.fetchall()
print(rows)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipython-input-1258080193.py in <cell line: 0>()
# ----> 1 q13 = cursor.execute("select name from Country WHERE CID =(select CID FROM M_Country GROUP BY CID ORDER BY COUNT(*) DESC LIMIT 1) ")
#       2 rows=cursor.fetchall()
#       3 print(rows)
#
# DatabaseError: database disk image is malformed

# %%
def q13_grader(q13):
  result = pd.read_sql_query(q13, conn)
  return result.iloc[0, 0] == "India"
print(q13_grader(q13))

# %% [markdown]
# ## 14. Write SQL query to get the year and number of movies per year having number of movies per year is greater than 100

# %%
q14 =cursor.execute( "select year,count(*) AS  number_movies FROM Movie GROUP BY year HAVING COUNT(*)>100 ")
rows=cursor.fetchall()
print(rows)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipython-input-107199903.py in <cell line: 0>()
# ----> 1 q14 =cursor.execute( "select year,count(*) AS  number_movies FROM Movie GROUP BY year HAVING COUNT(*)>100 ")
#       2 rows=cursor.fetchall()
#       3 print(rows)
#
# DatabaseError: database disk image is malformed

# %%
def q14_grader(q14):
  result = pd.read_sql_query(q14, conn)
  return result.shape==(13,2)
print(q14_grader(q14))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2508581650.py in <cell line: 0>()
#       2   result = pd.read_sql_query(q14, conn)
#       3   return result.shape==(13,2)
# ----> 4 print(q14_grader(q14))
#
# NameError: name 'q14' is not defined

# %% [markdown]
# ## 15. Write SQL query to get the Name and Language ID (LAID) corresponding to Malayalam language

# %%
q15 = cursor.execute("select Name , Laid from Language WHERE Name='Malayalam'")
rows=cursor.fetchall()
print(rows)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipython-input-2336230674.py in <cell line: 0>()
# ----> 1 q15 = cursor.execute("select Name , Laid from Language WHERE Name='Malayalam'")
#       2 rows=cursor.fetchall()
#       3 print(rows)
#
# DatabaseError: database disk image is malformed

# %%
def q15_grader(q15):
  result = pd.read_sql_query(q15, conn)
  print(result)
  return result[["Name", "LAID"]].values.tolist() == [['Malayalam', 19]]
print(q15_grader(q15))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1704386738.py in <cell line: 0>()
#       3   print(result)
#       4   return result[["Name", "LAID"]].values.tolist() == [['Malayalam', 19]]
# ----> 5 print(q15_grader(q15))
#
# NameError: name 'q15' is not defined

# %% [markdown]
# ## 16. Write SQL query to do inner join with movie table and M_Language table with MID colums

# %%
q16 = """select * FROM Movie M INNER JOIN M_Language ML on ML.MID=M.MID"""

# %%
def q16_grader(q16):
  result = pd.read_sql_query(q16, conn)
  return result
print(q16_grader(q16))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3995420853.py in <cell line: 0>()
#       2   result = pd.read_sql_query(q16, conn)
#       3   return result
# ----> 4 print(q16_grader(q16))
#
# NameError: name 'q16' is not defined

# %% [markdown]
# ## 17. Write SQL query to list title, year and rating of malayalam movies in the database by doing an inner join with movie table and M_Language table with MID column, also assuming language ID of malayalam movies as 19

# %%
q17 = """SELECT m.Title, m.Year, m.Rating FROM Movie AS m INNER JOIN M_Language AS ml ON m.MID = ml.MID WHERE ml.LanguageID = 19;"""

# %%
def q17_grader(q17):
  result = pd.read_sql_query(q17, conn)
  return result.shape==(16,3)
print(q17_grader(q17))
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2673         try:
# -> 2674             cur.execute(sql, *args)
#    2675             return cur
#
# OperationalError: near "INSER": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipython-input-317348278.py in <cell line: 0>()
#       2   result = pd.read_sql_query(q17, conn)
#       3   return result.shape==(16,3)
# ----> 4 print(q17_grader(q17))
#
# /tmp/ipython-input-317348278.py in q17_grader(q17)
#       1 def q17_grader(q17):
# ----> 2   result = pd.read_sql_query(q17, conn)
#       3   return result.shape==(16,3)
#       4 print(q17_grader(q17))
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     524
#     525     with pandasSQL_builder(con) as pandas_sql:
# --> 526         return pandas_sql.read_query(
#     527             sql,
#     528             index_col=index_col,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2736         dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2737     ) -> DataFrame | Iterator[DataFrame]:
# -> 2738         cursor = self.execute(sql, params)
#    2739         columns = [col_desc[0] for col_desc in cursor.description]
#    2740
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2684
#    2685             ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2686             raise ex from exc
#    2687
#    2688     @staticmethod
#
# DatabaseError: Execution failed on sql 'INSER YOUR QUERY HERE;': near "INSER": syntax error

# %%
![ -f academic.db ] && rm academic.db

conn = sqlite3.connect("academic.db")
cursor = conn.cursor()

# %% [markdown]
# ## 18. Write SQL query to Create a table named students with two columns id (integer type) and name (varchar type)

# %%
cursor.execute("""
create table if not exists students(
  ID INTEGER PRIMARY KEY,
  Name TEXT NOT NULL)
  """)

# %%
conn.commit()

# %%
def q18_grader_a(q18):
  try:
    cursor.execute(q18)
    return True
  except:
    pass

def q18_grader_b(q19):
  result = pd.read_sql_query(q19, conn)
  return result.columns.tolist() == ['id', 'name']

q18b = """SELECT * FROM students;"""

print(q18_grader_a(q18a) and q18_grader_b(q18b))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2768463354.py in <cell line: 0>()
#      12 q18b = """SELECT * FROM students;"""
#      13
# ---> 14 print(q18_grader_a(q18a) and q18_grader_b(q18b))
#
# NameError: name 'q18a' is not defined

# %% [markdown]
# ## 19. Write SQL query to insert the values (1, 'Alice') into students table

# %%
cursor.execute("insert into students values (1,'Alice')")

# %%
cursor.execute("select * from students")
rows=cursor.fetchall()
for row in rows:
  print(row)

# %%
def q19_grader_a(q19_a):
  try:
    cursor.execute(q19_a)
  except:
    pass
  return True

def q19_grader_b(q19_b):
  result = pd.read_sql_query(q19_b, conn)
  return result.values.tolist() == [[1, 'Alice']]

q19_b = "SELECT * FROM students"
print(q19_grader_a(q19_a) and q19_grader_b(q19_b))

# %% [markdown]
# ## 20. Write SQL Query to add the following more information to students table
#
# | ID | Name    |
# |----|---------|
# | 2  | Bob     |
# | 3  | Charlie |

# %%
q20 = cursor.execute("insert into students values (2,'Bob'),(3,'Charlie') ")

# %%
cursor.execute("select * from students")
rows=cursor.fetchall()
for row in rows:
  print(row)

# %%
def q20_grader(q20):
  try:
    cursor.execute(q20)
  except:
    pass
  return True

def q20_grader_b(q20_b):
  result = pd.read_sql_query(q20_b, conn)
  return result.values.tolist() == [[1, 'Alice'], [2, 'Bob'], [3, 'Charlie']]

print(q20_grader(q20) and q20_grader_b(q19_b))
# Out:
# False

# %%
# conn.close()
