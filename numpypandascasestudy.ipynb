# %% [markdown]
# <a href="https://colab.research.google.com/github/LekshmiRM/python_assignments/blob/main/numpypandascasestudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Import numpy pandas**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **2.Load dataset using pd.read_csv()**

# %%
df=pd.read_csv('https://raw.githubusercontent.com/laxmimerit/All-CSV-ML-Data-Files-Download/master/IMDB-Movie-Data.csv')
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# **3) Display: shape, head, column names, datatypes, missing value**

# %%
#missing value
df.isnull().sum()
# Out:
# Rank                   0
# Title                  0
# Genre                  0
# Description            0
# Director               0
# Actors                 0
# Year                   0
# Runtime (Minutes)      0
# Rating                 0
# Votes                  0
# Revenue (Millions)     0
# Metascore             64
# Genre_count            0
# dtype: int64

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
#data type

df.dtypes
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
#head
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %% [markdown]
# **4) Check and remove duplicates**

# %%
#check duplicates

df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
#remove duplicates
df.drop_duplicates()
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# **5.Rename columns ("Title" > "Movie_Title")**

# %%
df.rename(columns={'Title' :'movie_title'},inplace=True)

# %%
df
# Out:
#      Rank              movie_title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df
# Out:
#      Rank              movie_title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# **6.Get unique genres**

# %%
unique=df['Genre'].unique()

# %%
print(unique)
# Out:
# ['Action,Adventure,Sci-Fi' 'Adventure,Mystery,Sci-Fi' 'Horror,Thriller'
#  'Animation,Comedy,Family' 'Action,Adventure,Fantasy' 'Comedy,Drama,Music'
#  'Comedy' 'Action,Adventure,Biography' 'Adventure,Drama,Romance'
#  'Adventure,Family,Fantasy' 'Biography,Drama,History'
#  'Animation,Adventure,Comedy' 'Action,Comedy,Drama' 'Action,Thriller'
#  'Biography,Drama' 'Drama,Mystery,Sci-Fi' 'Adventure,Drama,Thriller'
#  'Drama' 'Crime,Drama,Horror' 'Action,Adventure,Drama' 'Drama,Thriller'
#  'Action,Adventure,Comedy' 'Action,Horror,Sci-Fi' 'Adventure,Drama,Sci-Fi'
#  'Action,Adventure,Western' 'Comedy,Drama' 'Horror'
#  'Adventure,Drama,Fantasy' 'Action,Crime,Thriller' 'Action,Crime,Drama'
#  'Adventure,Drama,History' 'Crime,Horror,Thriller' 'Drama,Romance'
#  'Comedy,Drama,Romance' 'Horror,Mystery,Thriller' 'Crime,Drama,Mystery'
#  'Drama,Romance,Thriller' 'Drama,History,Thriller' 'Action,Drama,Thriller'
#  'Drama,History' 'Action,Drama,Romance' 'Drama,Fantasy' 'Action,Sci-Fi'
# ...

# %% [markdown]
# **7.Extract number of genres per movie**

# %%
df['Genre_count']=df['Genre'].str.split(',').str.len()
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# **8.Handle missing values in 'Revenue (Millions)' and 'Metascore**

# %%
df['Revenue (Millions)'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Metascore'].isna().sum()
# Out:
# np.int64(64)

# %%
df.dropna(subset=['Revenue (Millions)','Metascore'],inplace=True)

# %% [markdown]
# **9.Top 5 movies by Rating**

# %%
rating=df.sort_values(by=["Rating"],ascending=False)
rating
# Out:
#      Rank                 Title                     Genre  \
# 54     55       The Dark Knight        Action,Crime,Drama
# 80     81             Inception   Action,Adventure,Sci-Fi
# 96     97         Kimi no na wa   Animation,Drama,Fantasy
# 36     37          Interstellar    Adventure,Drama,Sci-Fi
# 249   250      The Intouchables    Biography,Comedy,Drama
# ..    ...                   ...                       ...
# 968   969               Wrecker    Action,Horror,Thriller
# 890   891            The Intent               Crime,Drama
# 647   648              Tall Men   Fantasy,Horror,Thriller
# 871   872  Dragonball Evolution  Action,Adventure,Fantasy
# 829   830        Disaster Movie                    Comedy
#
#                                            Description           Director  \
# 54   When the menace known as the Joker wreaks havo...  Christopher Nolan
# 80   A thief, who steals corporate secrets through ...  Christopher Nolan
# ...

# %% [markdown]
# **10.Movies with highest/lowest revenue**

# %%
df['Revenue (Millions)'].idxmax()
# Out:
# np.int64(50)

# %%
df.loc[50,'Revenue (Millions)']
# Out:
# np.float64(936.63)

# %%
df['Revenue (Millions)'].idxmin()
# Out:
# np.int64(231)

# %%
df.loc[231,'Revenue (Millions)']
# Out:
# np.float64(0.0)

# %% [markdown]
# **11.Avg. rating by Director**

# %%
df[['Director','Rating']]
# Out:
#                  Director  Rating
# 0              James Gunn     8.1
# 1            Ridley Scott     7.0
# 2      M. Night Shyamalan     7.3
# 3    Christophe Lourdelet     7.2
# 4              David Ayer     6.2
# ..                    ...     ...
# 995             Billy Ray     6.2
# 996              Eli Roth     5.5
# 997            Jon M. Chu     6.2
# 998        Scot Armstrong     5.6
# 999      Barry Sonnenfeld     5.3
#
# [936 rows x 2 columns]

# %%
df.Rating.mean()
# Out:
# np.float64(6.729166666666667)

# %% [markdown]
# **12.Movies per year**

# %%
df['Year'].value_counts()
# Out:
# Year
# 2016    268
# 2015    123
# 2014     95
# 2013     86
# 2012     62
# 2010     59
# 2011     58
# 2009     49
# 2008     49
# 2007     46
# 2006     41
# Name: count, dtype: int64

# %% [markdown]
# **13.Movies with rating > 8 & revenue > 100M**

# %%
df[df["Rating"]>8] & (df['Revenue (Millions)']>100)[['Rating','Revenue (Millions)']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3660314264.py in <cell line: 0>()
# ----> 1 df[df["Rating"]>8] & (df['Revenue (Millions)']>100)[['Rating','Revenue (Millions)']]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1151             return self._get_rows_with_mask(key)
#    1152
# -> 1153         return self._get_with(key)
#    1154
#    1155     def _get_with(self, key):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in _get_with(self, key)
#    1192
#    1193         # handle the dup indexing case GH#4246
# -> 1194         return self.loc[key]
#    1195
#    1196     def _get_values_tuple(self, key: tuple):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
# ...

# %% [markdown]
# **14.Group by Director: avg Rating, Revenue**

# %%
df.groupby('Director').agg(rating=('Rating' ,'mean'),revenue=('Revenue (Millions)','sum'))
# Out:
#                      rating     revenue
# Director
# Aamir Khan             8.50    1.200000
# Abdellatif Kechiche    7.80    2.200000
# Adam Leon              6.50   82.956376
# Adam McKay             7.00  438.140000
# Adam Shankman          6.30  157.330000
# ...                     ...         ...
# Xavier Dolan           7.55   86.446376
# Yimou Zhang            6.10   45.130000
# Yorgos Lanthimos       7.20    8.810000
# Zack Snyder            7.04  975.740000
# Zackary Adler          5.10    6.530000
#
# [607 rows x 2 columns]

# %% [markdown]
# **15.Group by Year: count, avg Rating**

# %%
df.groupby('Year')['Rating'].agg(['count','mean'])
# Out:
#       count      mean
# Year
# 2006     41  7.143902
# 2007     46  7.130435
# 2008     49  6.716327
# 2009     49  6.944898
# 2010     59  6.820339
# 2011     58  6.910345
# 2012     62  6.933871
# 2013     86  6.811628
# 2014     95  6.816842
# 2015    123  6.573984
# 2016    268  6.466791

# %% [markdown]
# 16.Create a new column Profitability:
# a) Revenue divided by Duration
# b) Find top 10 most profitable movies **bold text**

# %%
df['Profitability']=df['Revenue (Millions)']/df['Runtime (Minutes)']
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# 17.17) Create a column that categorizes movies by rating:
# a) Rating < 6: Poor
# b) 6 ≤ Rating < 7.5: Average
# c) Rating ≥ 7.5: Excellent

# %%
df['movies_rating']=df['Rating'].apply(lambda x: 'Excellent' if x>=7.5 else 'Average' if x<6 else 'Poor')
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...
